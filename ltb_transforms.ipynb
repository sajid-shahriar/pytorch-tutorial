# %% [markdown]
# <a href="https://colab.research.google.com/github/sajid-shahriar/pytorch-tutorial/blob/main/ltb_transforms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn.functional as F

from torchvision import datasets
from torchvision.transforms import v2

# %% [markdown]
# All torchvision datasets have two parameters transforms and target_transforms to modify the features and label respectively.
#
# Lambda transforms apply any user-defined lambda function.

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=v2.Compose([
        v2.ToImage(),
        v2.ToDtype(torch.float32, scale=True)
    ]),
    target_transform=v2.Lambda(
        lambda y: F.one_hot(torch.tensor(y), num_classes=10).float()
    )
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 13.3MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 212kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.91MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 19.0MB/s]
